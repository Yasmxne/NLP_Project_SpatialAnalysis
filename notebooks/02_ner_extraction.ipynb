# %% [markdown]
# ## **NER extraction**

# %%
import sys
sys.path.append("..")

from src.ner import add_locations_column

# %%
import sys
!"{sys.executable}" -m spacy download fr_core_news_md
# Out:
# ...
#      ---------------------------------------- 0.0/45.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/45.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/45.8 MB 435.7 kB/s eta 0:01:46
#      --------------------------------------- 0.1/45.8 MB 871.5 kB/s eta 0:00:53
#      ---------------------------------------- 0.3/45.8 MB 2.3 MB/s eta 0:00:21
#      ---------------------------------------- 0.5/45.8 MB 2.8 MB/s eta 0:00:17
#      ---------------------------------------- 0.6/45.8 MB 2.9 MB/s eta 0:00:16
#       --------------------------------------- 0.6/45.8 MB 2.4 MB/s eta 0:00:19
#       --------------------------------------- 0.9/45.8 MB 2.7 MB/s eta 0:00:17
#       --------------------------------------- 1.1/45.8 MB 3.1 MB/s eta 0:00:15
#      - -------------------------------------- 1.3/45.8 MB 3.2 MB/s eta 0:00:14
#      - -------------------------------------- 1.5/45.8 MB 3.3 MB/s eta 0:00:14
# ...

# %%
import pandas as pd
from src.preprocess import clean_text

df_merged = pd.read_csv("../data/processed/merged_corpus.csv")
df_merged["text_clean"] = df_merged["text"].apply(clean_text)
df_sample = df_merged.head(1000)
df_ner = add_locations_column(df_sample, text_col="text_clean")
# Out:
# C:\Users\Narji\AppData\Local\Temp\ipykernel_20676\2838420624.py:4: DtypeWarning: Columns (0: identifiant de circonscription) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_merged = pd.read_csv("../data/processed/merged_corpus.csv")

# %%
df_ner.to_pickle("../data/processed/df_ner3.pkl")
